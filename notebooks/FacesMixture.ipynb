# %%
import sys

from pathlib import Path

sys.path.append("../src")

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.decomposition import FastICA

# %%
from utils.image_ops import image_to_np_array, mix_images
from utils.path_helpers import get_data_root

# %%
FOUR_FACES_PATH = get_data_root() / "four_faces/grayscale"

# %%
image_paths = list(FOUR_FACES_PATH.glob("*.png"))

# %%
input_images = [image_to_np_array(image_path) for image_path in image_paths]

# %%
N = len(input_images)
mixing_matrix = np.random.rand(N, N)
mixing_matrix
# Out:
# array([[0.22825173, 0.3957725 , 0.82963278, 0.18626725],
#        [0.52553171, 0.50235693, 0.25068277, 0.81843148],
#        [0.03182619, 0.27509478, 0.80999621, 0.78758272],
#        [0.48946856, 0.35167604, 0.11803794, 0.05895461]])

# %%
mixed_images = mix_images(image_paths, mixing_matrix)

#images = [image_to_np_array(image_path) for image_path in input_images]

# %%
from utils.plot_ops import plot_dependency

# %%
plot_dependency(input_images, normalize=True)
# Out:
# <class 'numpy.ndarray'>

# %%
mixed_images = [mixed_images[:, i].reshape(input_images[i].shape) for i in range(len(input_images))]
plot_dependency(mixed_images, normalize=)

# %%
mixed_images[:, 0].reshape(input_images[0].shape)

# %%
plt.figure(figsize=(24, 9))

# %%
for i in range(len(input_images)):
    plt.subplot(1, N, i+1), plt.imshow(input_images[i], cmap="gray"), plt.title(f"Original {i}")

# %%
for i in range(len(input_images)):
    print(input_images[i].max(), input_images[i].min())
    plt.subplot(2, N, i+1), plt.imshow(mixed_images[:, i].reshape(input_images[i].shape), cmap="gray"), plt.title(f"Mixture {i}")

# %%
fastica = FastICA(n_components=N, max_iter=1000)

# %%
#mixed_images  = mixed_images / 
transformed = fastica.fit_transform(mixed_images)

# %%
for i in range(len(input_images)):
    min_val = transformed[:, i].min()
    max_val = transformed[:, i].max()
    print(min_val, max_val)
    t = transformed[:, i] - min_val
    print(t.min(), t.max())
    t_norm = t / (max_val - min_val) * 255
    t_norm = t_norm.astype(np.uint8)
    t_norm = np.invert(t_norm)
    #plt.subplot(2, N, i+1), plt.imshow(transformed[:, i].reshape(input_images[i].shape), cmap="gray"), plt.title(f"Mixture {i}")
    plt.subplot(2, N, i+1), plt.imshow(t_norm.reshape(input_images[i].shape), cmap="gray"), plt.title(f"Mixture {i}")

# %%
transformed.shape

# %%
input_images[0].max()

# %%
import numpy as np
from scipy import signal

np.random.seed(0)
n_samples = 2000
time = np.linspace(0, 8, n_samples)

s1 = np.sin(2 * time)  # Signal 1 : sinusoidal signal
s2 = np.sign(np.sin(3 * time))  # Signal 2 : square signal
s3 = signal.sawtooth(2 * np.pi * time)  # Signal 3: saw tooth signal

S = np.c_[s1, s2, s3]
S += 0.2 * np.random.normal(size=S.shape)  # Add noise

S /= S.std(axis=0)  # Standardize data
# Mix data
A = np.array([[1, 1, 1], [0.5, 2, 1.0], [1.5, 1.0, 2.0]])  # Mixing matrix
X = np.dot(S, A.T)  # Generate observations

# %%
mneica.current_fit

# %%
mixed_images.shape

# %%
S.shape

# %%
s1.shape

# %%
combined_images = np.vstack(flat_images).T
combined_images.shape

# %%
combined_images = np.hstack(flat_images)
combined_images.shape

# %%
mixed_images.shape
